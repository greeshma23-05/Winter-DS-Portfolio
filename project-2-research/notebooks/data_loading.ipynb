# %%
import numpy as np
np.random.seed(42)

# %%
import pandas as pd

crime_path = "../data/raw/MD_crime.csv"
college_path = "../data/raw/MD_college_enrollment.csv"

crime_df = pd.read_csv(crime_path)
college_df = pd.read_csv(college_path)

print("Crime data shape: ", crime_df.shape)
print("College enrollment data shape: ", college_df.shape)

crime_df.head()
# Out:
# Crime data shape:  (1104, 38)
# College enrollment data shape:  (28, 10)
#       JURISDICTION  YEAR  POPULATION  MURDER  RAPE  ROBBERY  AGG. ASSAULT  \
# 0  Allegany County  1975       79655       3     5       20           114
# 1  Allegany County  1976       83923       2     2       24            59
# 2  Allegany County  1977       82102       3     7       32            85
# 3  Allegany County  1978       79966       1     2       18            81
# 4  Allegany County  1979       79721       1     7       18            84
#
#    B & E  LARCENY THEFT  M/V THEFT  ...  B & E PER 100,000 PEOPLE  \
# 0    669           1425         93  ...                     839.9
# 1    581           1384         73  ...                     692.3
# 2    592           1390        102  ...                     721.1
# 3    539           1390        100  ...                     674.0
# 4    502           1611         99  ...                     629.7
#
# ...

# %%
crime_df.info()
college_df.info()

crime_df.columns
college_df.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1104 entries, 0 to 1103
# Data columns (total 38 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   JURISDICTION                                           1104 non-null   object
#  1   YEAR                                                   1104 non-null   int64
#  2   POPULATION                                             1104 non-null   int64
#  3   MURDER                                                 1104 non-null   int64
#  4   RAPE                                                   1104 non-null   int64
#  5   ROBBERY                                                1104 non-null   int64
#  6   AGG. ASSAULT                                           1104 non-null   int64
#  7   B & E                                                  1104 non-null   int64
# ...

# %%
crime_df.to_csv("../data/processed/crime_base.csv", index=False)
college_df.to_csv("../data/processed/college_base.csv", index=False)
